# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
A=['a','1',12,23,45,56,True,False]
print(A)
type(A)
# Out:
# ['a', '1', 12, 23, 45, 56, True, False]
# list

# %%
for i in A:
    print(f'Element Value : {i},DataType = {(i)}')
# Out:
# Element Value : a,DataType = a
# Element Value : 1,DataType = 1
# Element Value : 12,DataType = 12
# Element Value : 23,DataType = 23
# Element Value : 45,DataType = 45
# Element Value : 56,DataType = 56
# Element Value : True,DataType = True
# Element Value : False,DataType = False

# %%
import pandas as pd

# %%
M= {
    'Id' : [1,2,3],
    'Car_Owner' : ['Mayank','Rahul','Sushant'],
    'Car_Name' : ['Kia Seltos','Suzuki Swift','Kia Sonet'],
    'Engine' : ['Diesel','Petrol','Petrol'],
    'Engine_Size' : [4,3,3],
    'Drive' : ['Auto','Manual','Auto'],
    'Price' : [17,10,8]}

# %%
import pandas as pd
df=pd.DataFrame(M)
df
# Out:
#    Id Car_Owner      Car_Name  Engine  Engine_Size   Drive  Price
# 0   1    Mayank    Kia Seltos  Diesel            4    Auto     17
# 1   2     Rahul  Suzuki Swift  Petrol            3  Manual     10
# 2   3   Sushant     Kia Sonet  Petrol            3    Auto      8

# %%
A
# Out:
# ['a', '1', 12, 23, 45, 56, True, False]

# %%
A.append('EtlHive')

# %%
A
# Out:
# ['a', '1', 12, 23, 45, 56, True, False, 'EtlHive']

# %%
dct={'Roll_No':[1,2,3],
     'Name':['JAY','CHIKU','KITTU'],
     'Class':['4th','UKG','LKG'],
     'Age':[8,3,1]}

# %%
dct
# Out:
# {'Roll_No': [1, 2, 3],
#  'Name': ['JAY', 'CHIKU', 'KITTU'],
#  'Class': ['4th', 'UKG', 'LKG'],
#  'Age': [8, 3, 1]}

# %%
df=pd.DataFrame(dct)
df
# Out:
#    Roll_No   Name Class  Age
# 0        1    JAY   4th    8
# 1        2  CHIKU   UKG    3
# 2        3  KITTU   LKG    1

# %%
dct['Age']
# Out:
# [8, 3, 1]

# %%
dct['Hobbies']=['cricket','Carrom','Walk']
dct
# Out:
# {'Roll_No': [1, 2, 3],
#  'Name': ['JAY', 'CHIKU', 'KITTU'],
#  'Class': ['4th', 'UKG', 'LKG'],
#  'Age': [8, 3, 1],
#  'Hobbies': ['cricket', 'Carrom', 'Walk']}

# %%
dct.keys()
# Out:
# dict_keys(['Roll_No', 'Name', 'Class', 'Age', 'Hobbies'])

# %%
dct.values()
# Out:
# dict_values([[1, 2, 3], ['JAY', 'CHIKU', 'KITTU'], ['4th', 'UKG', 'LKG'], [8, 3, 1], ['cricket', 'Carrom', 'Walk']])

# %%
dct.items()
# Out:
# dict_items([('Roll_No', [1, 2, 3]), ('Name', ['JAY', 'CHIKU', 'KITTU']), ('Class', ['4th', 'UKG', 'LKG']), ('Age', [8, 3, 1]), ('Hobbies', ['cricket', 'Carrom', 'Walk'])])

# %% [markdown]
# ## Take 2 numbers as input from user
# Check divisibilty of number a with number b
#
# Please enter a number : Please enter a divsior :

# %%
a=int(input('Please Enter a Positive Number :'))
b=int(input('Please Enter a Divisor :'))
if a%b==0:
    print('\n================================\n')
    print(f'The Given Number {a} is Divisible by {b}')
else:
    print('\n********************************\n')
    print(f'The Given Number {a} is Not Divisible By {b}')
# Out:
# Please Enter a Positive Number :86
# Please Enter a Divisor :12
#
# ********************************
#
# The Given Number 86 is Not Divisible By 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dct = {'Id':[1,2,3],
      'Car Owner':['Mayank','Rahul','Sushant'],
      'Car Name':['Kia Seltos','Suzuki Swift','Kia Sonet'],
      'Engine':['Diesel','Petrol','Petrol'],
       'Engine Size':[4,3,3],
      'Drive':['Auto','Manual','Auto'],
      'Price':[17,10,8]}

# %%
dct
# Out:
# {'Id': [1, 2, 3],
#  'Car Owner': ['Mayank', 'Rahul', 'Sushant'],
#  'Car Name': ['Kia Seltos', 'Suzuki Swift', 'Kia Sonet'],
#  'Engine': ['Diesel', 'Petrol', 'Petrol'],
#  'Engine Size': [4, 3, 3],
#  'Drive': ['Auto', 'Manual', 'Auto'],
#  'Price': [17, 10, 8]}

# %%
import pandas as pd
df=pd.DataFrame(dct)
df
# Out:
#    Id Car Owner      Car Name  Engine  Engine Size   Drive  Price
# 0   1    Mayank    Kia Seltos  Diesel            4    Auto     17
# 1   2     Rahul  Suzuki Swift  Petrol            3  Manual     10
# 2   3   Sushant     Kia Sonet  Petrol            3    Auto      8

# %%
df.shape
# Out:
# (3, 7)

# %%
df.columns
# Out:
# Index(['Id', 'Car Owner', 'Car Name', 'Engine', 'Engine Size', 'Drive',
#        'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id              int64
# Car Owner      object
# Car Name       object
# Engine         object
# Engine Size     int64
# Drive          object
# Price           int64
# dtype: object

# %%
df.sum()['Price']
# Out:
# 35

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df.mean()['Price']
# Out:
# 11.666666666666666

# %%
df.mean()['Engine Size']
# Out:
# 3.3333333333333335

# %%
df.sort_values(by='Price')
# Out:
#    Id Car Owner      Car Name  Engine  Engine Size   Drive  Price
# 2   3   Sushant     Kia Sonet  Petrol            3    Auto      8
# 1   2     Rahul  Suzuki Swift  Petrol            3  Manual     10
# 0   1    Mayank    Kia Seltos  Diesel            4    Auto     17

# %%
df.sort_values(by='Car Owner')
# Out:
#    Id Car Owner      Car Name  Engine  Engine Size   Drive  Price
# 0   1    Mayank    Kia Seltos  Diesel            4    Auto     17
# 1   2     Rahul  Suzuki Swift  Petrol            3  Manual     10
# 2   3   Sushant     Kia Sonet  Petrol            3    Auto      8

# %%
df.groupby(by='Engine').sum()['Price']
# Out:
# Engine
# Diesel    17
# Petrol    18
# Name: Price, dtype: int64

# %% [markdown]
# ## Reading the data in CSV format

# %%
import os
os.chdir('C:/Datasets/')

# %%
import pandas as pd
df=pd.read_csv('laptopPrice.csv')

# %%
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',500)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8    Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9      acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10     acer             AMD        Ryzen 5            10th   4 GB     DDR4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %% [markdown]
# ## How many differnt brands are present in dataset

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %% [markdown]
# ## Count of each Laptop brand in dataset

# %%
df['brand'].value_counts()
# Out:
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: brand, dtype: int64

# %% [markdown]
# ## Count of processors

# %%
df['processor_brand'].value_counts()
# Out:
# Intel    610
# AMD      189
# M1        24
# Name: processor_brand, dtype: int64

# %% [markdown]
# ## Finding top 5 most expensive laptops

# %%
df.sort_values(by='Price',ascending=False).head(5)[Fi['brand','Price']]
# Out:
#      brand   Price
# 594   ASUS  441990
# 621  APPLE  309990
# 590   ASUS  299990
# 433    MSI  291190
# 547    MSI  279990

# %% [markdown]
# ## Finding top 5 most expensive Lenovo laptops

# %%
df[df['brand']=='Lenovo'].sort_values(by='Price',ascending=False).head(5)[['brand','processor_name','processor_gnrtn','Price']]
# Out:
#       brand processor_name processor_gnrtn   Price
# 593  Lenovo        Core i9            10th  265998
# 523  Lenovo        Core i7             8th  244801
# 574  Lenovo        Core i7            10th  234990
# 563  Lenovo        Core i7             9th  229900
# 528  Lenovo        Core i7            10th  211753

# %%
df[df['brand']=='APPLE'].sort_values(by='Price',ascending=False).head(5)[['brand','processor_name','processor_gnrtn','Price']]
# Out:
#      brand processor_name processor_gnrtn   Price
# 621  APPLE             M1            10th  309990
# 620  APPLE             M1            10th  243990
# 622  APPLE             M1            10th  225990
# 619  APPLE             M1            10th  225990
# 614  APPLE             M1            10th  225990

# %%
df[df['brand']=='APPLE'].sort_values(by='Price',ascending=True).head(5)[['brand','processor_name','processor_gnrtn','Price']]
# Out:
#      brand processor_name processor_gnrtn   Price
# 599  APPLE             M1            10th   85990
# 605  APPLE             M1            10th   85990
# 609  APPLE             M1            10th  101990
# 608  APPLE             M1            10th  103990
# 616  APPLE             M1            10th  104990

# %%
df[df['brand']=='DELL'].sort_values(by='Price', ascending=False).head(5)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 201  DELL           Intel        Core i5            10th   8 GB   LPDDR4
# 514  DELL           Intel        Core i7            11th  16 GB  LPDDR4X
# 542  DELL           Intel        Core i7            11th  16 GB     DDR4
# 509  DELL           Intel        Core i7             8th  16 GB     DDR3
# 307  DELL           Intel        Core i5            11th   8 GB  LPDDR4X
#
#          ssd     hdd       os  os_bit graphic_card_gb      weight  \
# 201     0 GB  512 GB      DOS  32-bit            0 GB  ThinNlight
# 514   512 GB    0 GB  Windows  64-bit            0 GB  ThinNlight
# 542  1024 GB    0 GB  Windows  64-bit            2 GB      Casual
# 509   512 GB    0 GB  Windows  64-bit            0 GB  ThinNlight
# 307   512 GB    0 GB  Windows  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# ...

# %%
df[df['brand']=='DELL'].sort_values(by='Price', ascending=True).head(5)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 652  DELL             AMD        Ryzen 3   Not Available   8 GB     DDR4
# 631  DELL           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 629  DELL           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 40   DELL           Intel        Core i3            10th   4 GB     DDR4
# 639  DELL             AMD        Ryzen 3   Not Available   8 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 652    0 GB  1024 GB  Windows  64-bit            0 GB  ThinNlight
# 631  256 GB     0 GB  Windows  64-bit            0 GB      Casual
# 629  256 GB     0 GB  Windows  64-bit            0 GB  ThinNlight
# 40   256 GB     0 GB  Windows  64-bit            0 GB  ThinNlight
# 639  256 GB     0 GB  Windows  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice  Price   rating  Number of Ratings  \
# ...

# %% [markdown]
# ## Top 5 cheapest laptops

# %%
df.sort_values(by='Price').head(5)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 194  Lenovo           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
# 12    Avita           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 189    ASUS           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
# 188    ASUS           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
# 170    ASUS           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
#
#       ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 194  0 GB  512 GB  Windows  32-bit            0 GB  Casual  No warranty
# 12   0 GB  512 GB  Windows  64-bit            0 GB  Casual  No warranty
# 189  0 GB  512 GB  Windows  32-bit            0 GB  Casual  No warranty
# 188  0 GB  512 GB  Windows  64-bit            0 GB  Casual  No warranty
# 170  0 GB  512 GB  Windows  32-bit            0 GB  Casual  No warranty
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %% [markdown]
# ## Brandwise average price of laptops

# %%
df.groupby(by='brand').mean()['Price']
# Out:
# brand
# APPLE     151707.857143
# ASUS       78937.602410
# Avita      65157.428571
# DELL       60934.662252
# HP         73640.272059
# Lenovo     72920.208333
# MSI        98713.020000
# acer       72420.039216
# Name: Price, dtype: float64

# %%
df.groupby(by='brand').mean()['Price'].sort_values()
# Out:
# brand
# DELL       60934.662252
# Avita      65157.428571
# acer       72420.039216
# Lenovo     72920.208333
# HP         73640.272059
# ASUS       78937.602410
# MSI        98713.020000
# APPLE     151707.857143
# Name: Price, dtype: float64

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8    Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9      acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10     acer             AMD        Ryzen 5            10th   4 GB     DDR4
# ...

# %% [markdown]
# ## Finding out top rated laptops

# %%
df.sort_values(by='Number of Ratings',ascending=False).head(5)[['brand','Price','Number of Ratings']]
# Out:
#      brand   Price  Number of Ratings
# 21    ASUS   23990              15279
# 196   acer   50990              10966
# 653     HP   39490               7291
# 610  APPLE  104990               6725
# 616  APPLE  104990               6725

# %%
df.sort_values(by='rating',ascending=False).head(5)[['brand','Price','rating']]
# Out:
#      brand   Price   rating
# 361     HP  126000  5 stars
# 493     HP   93190  5 stars
# 621  APPLE  309990  5 stars
# 514   DELL  135300  5 stars
# 171   DELL   41490  5 stars

# %%
a=df.query("rating=='5 stars'")
a
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 46   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 78   Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 171    DELL           Intel        Core i3            10th   8 GB     DDR4
# 252      HP           Intel        Core i5            11th   8 GB  LPDDR4X
# 283    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 361      HP           Intel        Core i5            10th   8 GB     DDR4
# 381    ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 465    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 473    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 493      HP           Intel        Core i7            11th  16 GB     DDR4
# 514    DELL           Intel        Core i7            11th  16 GB  LPDDR4X
# ...

# %%
a.sort_values(by='Number of Ratings',ascending=False)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 171    DELL           Intel        Core i3            10th   8 GB     DDR4
# 473    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 283    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 514    DELL           Intel        Core i7            11th  16 GB  LPDDR4X
# 46   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 381    ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 493      HP           Intel        Core i7            11th  16 GB     DDR4
# 252      HP           Intel        Core i5            11th   8 GB  LPDDR4X
# 565    ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 621   APPLE              M1             M1            10th  32 GB     DDR4
# 805    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# ...

# %%
b = df.sort_values(by=['rating','Number of Ratings'],ascending=False)
b
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 171    DELL           Intel        Core i3            10th   8 GB     DDR4
# 473    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 283    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 514    DELL           Intel        Core i7            11th  16 GB  LPDDR4X
# 46   Lenovo           Intel        Core i3            10th   8 GB     DDR4
# 381    ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 493      HP           Intel        Core i7            11th  16 GB     DDR4
# 252      HP           Intel        Core i5            11th   8 GB  LPDDR4X
# 565    ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 621   APPLE              M1             M1            10th  32 GB     DDR4
# 805    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# ...

# %%
b.to_csv('Rating Sorted.csv',index=False)

# %% [markdown]
# ## Find out average price according to processor brands

# %%
df.groupby(by='processor_brand').mean()[['Price']]
# Out:
#                          Price
# processor_brand
# AMD               76614.481481
# Intel             73976.039344
# M1               148156.666667

# %%
c=df.groupby(by=['processor_brand','brand']).mean()[['Price']]
c
# Out:
#                                 Price
# processor_brand brand
# AMD             ASUS     98378.030303
#                 DELL     53808.451613
#                 HP       66911.590909
#                 Lenovo   72904.461538
#                 MSI      75704.285714
#                 acer     63304.600000
# Intel           APPLE   173015.000000
#                 ASUS     71926.300546
#                 Avita    65157.428571
#                 DELL     62775.600000
#                 HP       76858.336957
#                 Lenovo   72923.677966
#                 MSI     102458.627907
#                 acer     76218.138889
# M1              APPLE   148156.666667

# %%
c.plot(kind='bar')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='processor_brand,brand'>

# %% [markdown]
# ## Generation wise averge price

# %%
df.groupby(by='processor_gnrtn').mean()['Price']
# Out:
# processor_gnrtn
# 10th              89624.563725
# 11th              72072.050898
# 12th             239990.000000
# 4th               52490.000000
# 7th               57174.111111
# 8th               84676.682927
# 9th               87891.666667
# Not Available     68976.373333
# Name: Price, dtype: float64

# %%
df.query("`processor_gnrtn`=='7th'and `processor_name`=='Core i3'").sort_values(by='Price')
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 158    HP           Intel        Core i3             7th   8 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 22   0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 158  0 GB  1024 GB  Windows  64-bit            2 GB  Casual  No warranty
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 22           No       No  32955  4 stars                311                 27
# 158          No       No  49279  4 stars                 38                  3

# %%
df[df['processor_gnrtn']=='11th'].sort_values(by='Price')
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 24     ASUS           Intel        Core i3            11th   4 GB     DDR4
# 14     ASUS           Intel        Core i3            11th   4 GB     DDR4
# 26     ASUS           Intel        Core i3            11th   4 GB     DDR4
# 42     ASUS           Intel        Core i3            11th   8 GB     DDR4
# 81     ASUS           Intel        Core i3            11th   4 GB     DDR4
# 161    acer           Intel        Core i3            11th   4 GB     DDR4
# 33     ASUS           Intel        Core i3            11th   8 GB     DDR4
# 32     ASUS           Intel        Core i3            11th   8 GB     DDR4
# 157    DELL           Intel        Core i3            11th   8 GB     DDR4
# 52     ASUS           Intel        Core i3            11th   8 GB     DDR4
# 166    ASUS           Intel        Core i3            11th   8 GB     DDR4
# ...

# %% [markdown]
# ## Find out laptops with 11th Gen, i5 processor and 50000 to 60000

# %%
df.query("`processor_gnrtn`=='11th'and `processor_name`=='Core i5' and Price>=50000 and Price<=60000").sort_values(by='Price')[['brand','Price']]
# Out:
#       brand  Price
# 442    ASUS  50990
# 222  Lenovo  51990
# 217  Lenovo  52990
# 221  Lenovo  52990
# 226    acer  52990
# 445    ASUS  52990
# 345    ASUS  53190
# 305    ASUS  53400
# 216      HP  53990
# 255  Lenovo  53990
# 215      HP  54990
# 458    DELL  54990
# 281  Lenovo  54990
# 293    DELL  55490
# 251     MSI  55490
# 303     MSI  55490
# 448    acer  55490
# 455    DELL  55790
# 344     MSI  55990
# 209    DELL  55990
# 314  Lenovo  55990
# 264  Lenovo  55990
# 244    acer  55999
# 240      HP  55999
# 447    acer  56990
# 446    DELL  57990
# 329    ASUS  57990
# 319    acer  57990
# 444    acer  57990
# 287      HP  57990
# 426    DELL  58090
# 243      HP  58340
# 463    DELL  58990
# 457    ASUS  58990
# 274    ASUS  58990
# 471    DELL  58990
# 431    DELL  58990
# 265    ASUS  59990
# 296    DELL  59990
# 254  Lenovo  59990
# 451  Lenovo  59990
# 246    ASUS  59990
# 282  Lenovo  59990
# 285  Lenovo  59990
# 278    ASUS  59990
# 263    ASUS  59990
# ...

# %% [markdown]
# ## Find out Lenovo Laptops With 10th generation and i7 processor and 8gb ram

# %%
df.query("`processor_gnrtn`=='10th'and `processor_name`=='Core i7' and `ram_gb`=='8 GB' and brand=='Lenovo'")[['brand','Price']]
# Out:
#       brand  Price
# 488  Lenovo  68990

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8    Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9      acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10     acer             AMD        Ryzen 5            10th   4 GB     DDR4
# ...

# %%
df['weight'].unique()
# Out:
# array(['Casual', 'ThinNlight', 'Gaming'], dtype=object)

# %%
df.query("weight=='Gaming' and brand=='Lenovo'")[['Price','processor_gnrtn','processor_name']]
# Out:
#      Price processor_gnrtn processor_name
# 285  59990            11th        Core i5
# 353  69899            10th        Core i5
# 387  60990            11th        Core i5
# 464  74590            10th        Core i5
# 472  74999            10th        Core i5
# 488  68990            10th        Core i7
# 492  79990            11th        Core i7
# 669  56990   Not Available        Ryzen 5
# 677  59490   Not Available        Ryzen 5
# 734  63990   Not Available        Ryzen 5

# %%
df.groupby(by='weight').sum()[['Price']]
# Out:
#                Price
# weight
# Casual      44342460
# Gaming       2894348
# ThinNlight  15924473
