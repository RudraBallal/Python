# %% [markdown]
# # DataFrame Operation 2

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import os 
os.chdir('c:/Datasets')

# %%
import pandas as pd
df = pd.read_csv('Cars93.csv')

# %%
display(df)
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
s = df.isna().sum()
s
# Out:
# id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                4
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
s[s>0]
# Out:
# AirBags            4
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
df.shape
# Out:
# (93, 28)

# %%
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                      int64
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# Make                   object
# dtype: object

# %% [markdown]
# ## Subsetting and Storing in Different Variables

# %%
df[['Manufacturer','Model','Price']]
# Out:
#    Manufacturer    Model  Price
# 0         Acura  Integra   15.9
# 1         Acura   Legend   33.9
# 2          Audi       90   29.1
# 3          Audi      100   37.7
# 4           BMW     535i   30.0
# ..          ...      ...    ...
# 88   Volkswagen  Eurovan   19.7
# 89   Volkswagen   Passat   20.0
# 90   Volkswagen  Corrado   23.3
# 91        Volvo      240   22.7
# 92        Volvo      850   26.7
#
# [93 rows x 3 columns]

# %%
df
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
A = df[['Manufacturer','Model','Price']]
A
# Out:
#    Manufacturer    Model  Price
# 0         Acura  Integra   15.9
# 1         Acura   Legend   33.9
# 2          Audi       90   29.1
# 3          Audi      100   37.7
# 4           BMW     535i   30.0
# ..          ...      ...    ...
# 88   Volkswagen  Eurovan   19.7
# 89   Volkswagen   Passat   20.0
# 90   Volkswagen  Corrado   23.3
# 91        Volvo      240   22.7
# 92        Volvo      850   26.7
#
# [93 rows x 3 columns]

# %% [markdown]
# ## Aggregation Operations

# %%
df.count()
# Out:
# id                    93
# Manufacturer          93
# Model                 93
# Type                  93
# Min.Price             93
# Price                 93
# Max.Price             93
# MPG.city              93
# MPG.highway           93
# AirBags               89
# DriveTrain            93
# Cylinders             93
# EngineSize            93
# Horsepower            93
# RPM                   93
# Rev.per.mile          93
# Man.trans.avail       93
# Fuel.tank.capacity    93
# Passengers            93
# Length                93
# Wheelbase             93
# Width                 93
# Turn.circle           93
# Rear.seat.room        91
# Luggage.room          82
# Weight                93
# Origin                93
# Make                  93
# dtype: int64

# %%
df.sum(numeric_only=True)
# Out:
# id                      4371.0
# Min.Price               1592.7
# Price                   1814.4
# Max.Price               2036.6
# MPG.city                2080.0
# MPG.highway             2705.0
# EngineSize               248.1
# Horsepower             13376.0
# RPM                   491100.0
# Rev.per.mile          216895.0
# Fuel.tank.capacity      1549.8
# Passengers               473.0
# Length                 17038.0
# Wheelbase               9667.0
# Width                   6452.0
# Turn.circle             3623.0
# Rear.seat.room          2532.5
# Luggage.room            1139.0
# Weight                285780.0
# dtype: float64

# %%
df.mean()
# Out:
# id                      47.000000
# Min.Price               17.125806
# Price                   19.509677
# Max.Price               21.898925
# MPG.city                22.365591
# MPG.highway             29.086022
# EngineSize               2.667742
# Horsepower             143.827957
# RPM                   5280.645161
# Rev.per.mile          2332.204301
# Fuel.tank.capacity      16.664516
# Passengers               5.086022
# Length                 183.204301
# Wheelbase              103.946237
# Width                   69.376344
# Turn.circle             38.956989
# Rear.seat.room          27.829670
# Luggage.room            13.890244
# Weight                3072.903226
# dtype: float64

# %%
df.mean()['Price']
# Out:
# 19.50967741935484

# %%
df.mean()['Luggage.room']
# Out:
# 13.890243902439025

# %%
df.max(numeric_only=True)
# Out:
# id                      93.0
# Min.Price               45.4
# Price                   61.9
# Max.Price               80.0
# MPG.city                46.0
# MPG.highway             50.0
# EngineSize               5.7
# Horsepower             300.0
# RPM                   6500.0
# Rev.per.mile          3755.0
# Fuel.tank.capacity      27.0
# Passengers               8.0
# Length                 219.0
# Wheelbase              119.0
# Width                   78.0
# Turn.circle             45.0
# Rear.seat.room          36.0
# Luggage.room            22.0
# Weight                4105.0
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# id                       1.0
# Min.Price                6.7
# Price                    7.4
# Max.Price                7.9
# MPG.city                15.0
# MPG.highway             20.0
# EngineSize               1.0
# Horsepower              55.0
# RPM                   3800.0
# Rev.per.mile          1320.0
# Fuel.tank.capacity       9.2
# Passengers               2.0
# Length                 141.0
# Wheelbase               90.0
# Width                   60.0
# Turn.circle             32.0
# Rear.seat.room          19.0
# Luggage.room             6.0
# Weight                1695.0
# dtype: float64

# %%
df.max(numeric_only=True)['Horsepower']
# Out:
# 300.0

# %%
df.min(numeric_only=True)['MPG.highway']
# Out:
# 20.0

# %% [markdown]
# ## Groupby Operations

# %%
df['Type'].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
df.groupby(by='Type').mean()
# Out:
#                 id  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# Type
# Compact  50.750000  15.693750  18.212500  20.725000  22.687500    29.875000
# Large    32.090909  22.936364  24.300000  25.672727  18.363636    26.727273
# Midsize  42.500000  24.113636  27.218182  30.313636  19.545455    26.727273
# Small    52.904762   8.428571  10.166667  11.904762  29.857143    35.476190
# Sporty   49.785714  16.857143  19.392857  21.957143  21.785714    28.785714
# Van      51.444444  16.200000  19.100000  22.033333  17.000000    21.888889
#
#          EngineSize  Horsepower          RPM  Rev.per.mile  \
# Type
# Compact    2.331250  131.000000  5362.500000   2475.625000
# Large      4.209091  179.454545  4672.727273   1626.818182
# Midsize    3.059091  173.090909  5336.363636   2221.363636
# Small      1.595238   91.000000  5633.333333   2817.380952
# Sporty     2.492857  160.142857  5392.857143   2314.285714
# Van        3.200000  149.444444  4744.444444   2106.111111
#
# ...

# %%
df.groupby(by='Type').mean()['Price']
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
df.groupby(by='Type').count()['Model']
# Out:
# Type
# Compact    16
# Large      11
# Midsize    22
# Small      21
# Sporty     14
# Van         9
# Name: Model, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
df.groupby(by='Type').max()['Price']
# Out:
# Type
# Compact    31.9
# Large      36.1
# Midsize    61.9
# Small      15.9
# Sporty     38.0
# Van        22.7
# Name: Price, dtype: float64

# %%
df.groupby(by='AirBags').mean()['Price']
# Out:
# AirBags
# Driver & Passenger    27.150000
# Driver only           21.026190
# None                  13.269697
# Name: Price, dtype: float64

# %%
df.groupby(by=['Type','AirBags']).mean()['Price']
# Out:
# Type     AirBags
# Compact  Driver & Passenger    16.650000
#          Driver only           20.977778
#          None                  13.860000
# Large    Driver & Passenger    20.700000
#          Driver only           23.266667
# Midsize  Driver & Passenger    38.683333
#          Driver only           24.163636
#          None                  15.800000
# Small    Driver only           11.220000
#          None                   9.837500
# Sporty   Driver & Passenger    17.533333
#          Driver only           21.400000
#          None                  18.850000
# Van      Driver only           20.533333
#          None                  18.383333
# Name: Price, dtype: float64

# %% [markdown]
# ## Sorting in DataFrames

# %%
df.sort_values(by='Price')
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 30  31           Ford   Festiva    Small        6.9    7.4        7.9
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 52  53          Mazda       323    Small        7.4    8.3        9.1
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 79  80         Subaru     Justy    Small        7.3    8.4        9.5
# ..  ..            ...       ...      ...        ...    ...        ...
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 10  11       Cadillac   Seville  Midsize       37.5   40.1       42.7
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 58  59  Mercedes-Benz      300E  Midsize       43.8   61.9       80.0
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
df.sort_values(by='Passengers')
# Out:
#     id Manufacturer       Model    Type  Min.Price  Price  Max.Price  \
# 56  57        Mazda        RX-7  Sporty       32.5   32.5       32.5
# 18  19    Chevrolet    Corvette  Sporty       34.6   38.0       41.5
# 39  40          Geo       Storm  Sporty       11.5   12.5       13.5
# 27  28        Dodge     Stealth  Sporty       18.5   25.8       33.1
# 33  34         Ford     Mustang  Sporty       10.8   15.9       21.0
# ..  ..          ...         ...     ...        ...    ...        ...
# 86  87       Toyota      Previa     Van       18.9   22.7       26.6
# 88  89   Volkswagen     Eurovan     Van       16.6   19.7       22.7
# 25  26        Dodge     Caravan     Van       13.6   19.0       24.4
# 15  16    Chevrolet  Lumina_APV     Van       14.7   16.3       18.0
# 16  17    Chevrolet       Astro     Van       14.7   16.6       18.6
#
#     MPG.city  MPG.highway      AirBags  ... Passengers Length  Wheelbase  \
# ...

# %%
df.sort_values(by='Price',ascending=False)
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 58  59  Mercedes-Benz      300E  Midsize       43.8   61.9       80.0
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 10  11       Cadillac   Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# ..  ..            ...       ...      ...        ...    ...        ...
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 79  80         Subaru     Justy    Small        7.3    8.4        9.5
# 52  53          Mazda       323    Small        7.4    8.3        9.1
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 30  31           Ford   Festiva    Small        6.9    7.4        7.9
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
df.sort_values(by='Width')
# Out:
#     id Manufacturer           Model   Type  Min.Price  Price  Max.Price  \
# 79  80       Subaru           Justy  Small        7.3    8.4        9.5
# 43  44      Hyundai           Excel  Small        6.8    8.0        9.2
# 87  88   Volkswagen             Fox  Small        8.7    9.1        9.5
# 82  83       Suzuki           Swift  Small        7.3    8.6       10.0
# 30  31         Ford         Festiva  Small        6.9    7.4        7.9
# ..  ..          ...             ...    ...        ...    ...        ...
# 17  18    Chevrolet         Caprice  Large       18.0   18.8       19.6
# 51  52      Lincoln        Town_Car  Large       34.4   36.1       37.8
# 7    8        Buick      Roadmaster  Large       22.6   23.7       24.9
# 16  17    Chevrolet           Astro    Van       14.7   16.6       18.6
# 37  38         Ford  Crown_Victoria  Large       20.1   20.9       21.7
#
#     MPG.city  MPG.highway      AirBags  ... Passengers Length  Wheelbase  \
# ...

# %%
df.sort_values(by='Width',ascending=False)
# Out:
#     id Manufacturer           Model   Type  Min.Price  Price  Max.Price  \
# 37  38         Ford  Crown_Victoria  Large       20.1   20.9       21.7
# 7    8        Buick      Roadmaster  Large       22.6   23.7       24.9
# 16  17    Chevrolet           Astro    Van       14.7   16.6       18.6
# 51  52      Lincoln        Town_Car  Large       34.4   36.1       37.8
# 17  18    Chevrolet         Caprice  Large       18.0   18.8       19.6
# ..  ..          ...             ...    ...        ...    ...        ...
# 30  31         Ford         Festiva  Small        6.9    7.4        7.9
# 87  88   Volkswagen             Fox  Small        8.7    9.1        9.5
# 38  39          Geo           Metro  Small        6.7    8.4       10.0
# 43  44      Hyundai           Excel  Small        6.8    8.0        9.2
# 79  80       Subaru           Justy  Small        7.3    8.4        9.5
#
#     MPG.city  MPG.highway      AirBags  ... Passengers Length  Wheelbase  \
# ...

# %%
pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',100)

# %%
df.sort_values(by='Type')
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 42  43          Honda          Accord  Compact       13.8   17.5       21.2
# 67  68     Oldsmobile         Achieva  Compact       13.0   13.5       14.0
# 64  65         Nissan          Altima  Compact       13.0   15.7       18.3
# 24  25          Dodge          Spirit  Compact       11.9   13.3       14.7
# 73  74        Pontiac         Sunbird  Compact        9.4   11.1       12.8
# 12  13      Chevrolet         Corsica  Compact       11.4   11.4       11.4
# 11  12      Chevrolet        Cavalier  Compact        8.5   13.4       18.3
# 57  58  Mercedes-Benz            190E  Compact       29.0   31.9       34.9
# 54  55          Mazda             626  Compact       14.3   16.5       18.7
# 32  33           Ford           Tempo  Compact       10.4   11.3       12.2
# 77  78           Saab             900  Compact       20.3   28.7       37.1
# ...

# %%
df['Type'].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
df.sort_values(by=['Type','MPG.city'])
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 57  58  Mercedes-Benz            190E  Compact       29.0   31.9       34.9
# 77  78           Saab             900  Compact       20.3   28.7       37.1
# 89  90     Volkswagen          Passat  Compact       17.6   20.0       22.4
# 91  92          Volvo             240  Compact       21.8   22.7       23.5
# 24  25          Dodge          Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford           Tempo  Compact       10.4   11.3       12.2
# 20  21       Chrysler         LeBaron  Compact       14.5   15.8       17.1
# 73  74        Pontiac         Sunbird  Compact        9.4   11.1       12.8
# 81  82         Subaru          Legacy  Compact       16.3   19.5       22.7
# 42  43          Honda          Accord  Compact       13.8   17.5       21.2
# ...

# %% [markdown]
# ## Find out car Types with average Price less than 20

# %%
s = df.groupby(by='Type').mean()['Price']
s
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
s[s<20]
# Out:
# Type
# Compact    18.212500
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
s[s<20].index
# Out:
# Index(['Compact', 'Small', 'Sporty', 'Van'], dtype='object', name='Type')

# %% [markdown]
# ## Find out top 5 most fuel economic cars on city

# %%
df.sort_values(by='MPG.city',ascending=False).head(5)
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 41           46  Driver only      Front         4         1.5         102
# 82           43         None      Front         3         1.3          70
# 79           37         None        4WD         3         1.2          73
# 83           37  Driver only      Front         4         1.5          82
#
#      RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  \
# ...

# %%
df.sort_values(by='MPG.city',ascending=False).head(5)[['Manufacturer','Model','MPG.city']]
# Out:
#    Manufacturer   Model  MPG.city
# 38          Geo   Metro        46
# 41        Honda   Civic        42
# 82       Suzuki   Swift        39
# 79       Subaru   Justy        33
# 83       Toyota  Tercel        32
