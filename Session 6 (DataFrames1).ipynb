# %% [markdown]
# # DataFrames Session 1

# %% [markdown]
# ### Creating DataFrames with dictionary

# %%
emp_data = {'emp_id':[101,102,103,104],
           'name':['mahi','ravi','jitu','viju'],
           'lname':['Ballal','Ballal','Ballal','Ballal'],
           'dept':['Engg','Dr','Hr','Admin'],
           'salary':[20000,30000,40000,50000]}

# %%
emp_data
# Out:
# {'emp_id': [101, 102, 103, 104],
#  'name': ['mahi', 'ravi', 'jitu', 'viju'],
#  'lname': ['Ballal', 'Ballal', 'Ballal', 'Ballal'],
#  'dept': ['Engg', 'Dr', 'Hr', 'Admin'],
#  'salary': [20000, 30000, 40000, 50000]}

# %%
type(emp_data)
# Out:
# dict

# %% [markdown]
# ## Building DataFrame

# %%
import pandas as pd
df = pd.DataFrame(emp_data)
df
# Out:
#    emp_id  name   lname   dept  salary
# 0     101  mahi  Ballal   Engg   20000
# 1     102  ravi  Ballal     Dr   30000
# 2     103  jitu  Ballal     Hr   40000
# 3     104  viju  Ballal  Admin   50000

# %%
df
# Out:
#    emp_id  name    lname   dept  salary
# 0     101  mahi  Ballal1   Engg   20000
# 1     102  ravi  Ballal2     Dr   30000
# 2     103  jitu  Ballal3     Hr   40000
# 3     104  viju  Ballal4  Admin   50000

# %%
df.shape
# Out:
# (4, 5)

# %%
row_num = df.shape[0]
row_num
# Out:
# 4

# %%
col_num = df.shape[1]
col_num
# Out:
# 5

# %%
df.columns
# Out:
# Index(['emp_id', 'name', 'lname', 'dept', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# emp_id     int64
# name      object
# lname     object
# dept      object
# salary     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   emp_id  4 non-null      int64
#  1   name    4 non-null      object
#  2   lname   4 non-null      object
#  3   dept    4 non-null      object
#  4   salary  4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 288.0+ bytes

# %%
emp_data
# Out:
# {'emp_id': [101, 102, 103, 104],
#  'name': ['mahi', 'ravi', 'jitu', 'viju'],
#  'lname': ['Ballal', 'Ballal', 'Ballal', 'Ballal'],
#  'dept': ['Engg', 'Dr', 'Hr', 'Admin'],
#  'salary': [20000, 30000, 40000, 50000]}

# %% [markdown]
# ## Creating DataFrames with list

# %%
emp_id = [101,102,103,104]
name1 = ['mahi','ravi','jitu','viju']
lname = ['Ballal','Ballal','Ballal','Ballal']
dept = ['engg','Dr','Hr','Admin']
salary = [20000,30000,40000,10000]

# %%
A = pd.DataFrame([emp_id,name1,lname,dept,salary])
A
# Out:
#         0       1       2       3
# 0     101     102     103     104
# 1    mahi    ravi    jitu    viju
# 2  Ballal  Ballal  Ballal  Ballal
# 3    engg      Dr      Hr   Admin
# 4   20000   30000   40000   10000

# %%
A = pd.DataFrame([emp_id,name1,lname,dept,salary]).T
A
# Out:
#      0     1       2      3      4
# 0  101  mahi  Ballal   engg  20000
# 1  102  ravi  Ballal     Dr  30000
# 2  103  jitu  Ballal     Hr  40000
# 3  104  viju  Ballal  Admin  10000

# %%
A.columns=['emp_id','name1','lname','dept','salary']
A
# Out:
#   emp_id name1   lname   dept salary
# 0    101  mahi  Ballal   engg  20000
# 1    102  ravi  Ballal     Dr  30000
# 2    103  jitu  Ballal     Hr  40000
# 3    104  viju  Ballal  Admin  10000

# %%
A.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
list(A.index)
# Out:
# [0, 1, 2, 3]

# %%
A.index= range(1,5)
A
# Out:
#   emp_id name1   lname   dept salary
# 1    101  mahi  Ballal   engg  20000
# 2    102  ravi  Ballal     Dr  30000
# 3    103  jitu  Ballal     Hr  40000
# 4    104  viju  Ballal  Admin  10000

# %%
A.index = ['S1','S2','S3','S4']
A
# Out:
#    emp_id name1    lname   dept salary
# S1    101  mahi   Ballal   engg  20000
# S2    102  ravi     Raut     Dr  30000
# S3    103  jitu   Davare     Hr  40000
# S4    104  viju  Ballal1  Admin  10000

# %% [markdown]
# ## Reading CSV File

# %%
import os
os.chdir("c:/Datasets")

# %%
import pandas as pd
A = pd.read_csv('50_startups.csv')
A
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
display(A)
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
type(A)
# Out:
# pandas.core.frame.DataFrame

# %%
A.shape
# Out:
# (50, 5)

# %%
A.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
A.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
import pandas as pd
import os
os.chdir("c:/Datasets")

# %%
D=pd.read_csv('50_startups.csv')

# %%
pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',100)

# %%
D=pd.read_csv('50_startups.csv')
D
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
D.shape
# Out:
# (50, 5)

# %%
D.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',100)

# %%
C=pd.read_csv("cars93.csv")
C
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %%
pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',100)

# %%
C.isna().sum()
# Out:
# id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                4
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
C
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %%
C[(C['Type']=='Van')&(C['Price']>20)]
# Out:
#     id Manufacturer   Model Type  Min.Price  Price  Max.Price  MPG.city  \
# 86  87       Toyota  Previa  Van       18.9   22.7       26.6        18
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 86           22  Driver only        4WD         4         2.4         138
#
#      RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  \
# 86  5000          2515             Yes                19.8           7
#
#     Length  Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  \
# 86     187        113     71           41            35.0           NaN
#
#     Weight   Origin           Make
# 86    3785  non-USA  Toyota Previa

# %%
C.describe().T
# Out:
#                     count         mean         std     min     25%     50%  \
# id                   93.0    47.000000   26.990739     1.0    24.0    47.0
# Min.Price            93.0    17.125806    8.746029     6.7    10.8    14.7
# Price                93.0    19.509677    9.659430     7.4    12.2    17.7
# Max.Price            93.0    21.898925   11.030457     7.9    14.7    19.6
# MPG.city             93.0    22.365591    5.619812    15.0    18.0    21.0
# MPG.highway          93.0    29.086022    5.331726    20.0    26.0    28.0
# EngineSize           93.0     2.667742    1.037363     1.0     1.8     2.4
# Horsepower           93.0   143.827957   52.374410    55.0   103.0   140.0
# RPM                  93.0  5280.645161  596.731690  3800.0  4800.0  5200.0
# Rev.per.mile         93.0  2332.204301  496.506525  1320.0  1985.0  2340.0
# Fuel.tank.capacity   93.0    16.664516    3.279370     9.2    14.5    16.4
# ...

# %%
C[(C['Type']=='Large') & (C['Min.Price']>30)]
# Out:
#     id Manufacturer     Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 9   10     Cadillac   DeVille  Large       33.0   34.7       36.3        16
# 51  52      Lincoln  Town_Car  Large       34.4   36.1       37.8        18
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 9            25  Driver only      Front         8         4.9         200
# 51           26          NaN       Rear         8         4.6         210
#
#      RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  \
# 9   4100          1510              No                18.0           6
# 51  4600          1840              No                20.0           6
#
#     Length  Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  \
# 9      206        114     73           43            35.0          18.0
# 51     219        117     77           45            31.5          22.0
#
#     Weight Origin              Make
# 9     3620    USA  Cadillac DeVille
# ...

# %% [markdown]
# # Data Subsetting

# %%
D
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
D.PROFIT
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: PROFIT, dtype: float64

# %%
D[['RND','PROFIT']]
# Out:
#           RND     PROFIT
# 0   165349.20  192261.83
# 1   162597.70  191792.06
# 2   153441.51  191050.39
# 3   144372.41  182901.99
# 4   142107.34  166187.94
# 5   131876.90  156991.12
# 6   134615.46  156122.51
# 7   130298.13  155752.60
# 8   120542.52  152211.77
# 9   123334.88  149759.96
# 10  101913.08  146121.95
# 11  100671.96  144259.40
# 12   93863.75  141585.52
# 13   91992.39  134307.35
# 14  119943.24  132602.65
# 15  114523.61  129917.04
# 16   78013.11  126992.93
# 17   94657.16  125370.37
# 18   91749.16  124266.90
# 19   86419.70  122776.86
# 20   76253.86  118474.03
# 21   78389.47  111313.02
# 22   73994.56  110352.25
# 23   67532.53  108733.99
# 24   77044.01  108552.04
# 25   64664.71  107404.34
# 26   75328.87  105733.54
# 27   72107.60  105008.31
# 28   66051.52  103282.38
# 29   65605.48  101004.64
# 30   61994.48   99937.59
# 31   61136.38   97483.56
# 32   63408.86   97427.84
# 33   55493.95   96778.92
# 34   46426.07   96712.80
# 35   46014.02   96479.51
# ...

# %% [markdown]
# ## Subsetting Rows
#
# 1.iloc[column_index,row_index]
#
# 2.loc[column_index,row_index]

# %%
D.iloc[40:46,:]
# Out:
#          RND      ADMIN        MKT       STATE    PROFIT
# 40  28754.33  118546.05  172795.67  California  78239.91
# 41  27892.92   84710.77  164470.71     Florida  77798.83
# 42  23640.93   96189.63  148001.11  California  71498.49
# 43  15505.73  127382.30   35534.17    New York  69758.98
# 44  22177.74  154806.14   28334.72  California  65200.33
# 45   1000.23  124153.04    1903.93    New York  64926.08

# %%
D.loc[40:44,:]
# Out:
#          RND      ADMIN        MKT       STATE    PROFIT
# 40  28754.33  118546.05  172795.67  California  78239.91
# 41  27892.92   84710.77  164470.71     Florida  77798.83
# 42  23640.93   96189.63  148001.11  California  71498.49
# 43  15505.73  127382.30   35534.17    New York  69758.98
# 44  22177.74  154806.14   28334.72  California  65200.33

# %%
D.iloc[[42,44],:]
# Out:
#          RND      ADMIN        MKT       STATE    PROFIT
# 42  23640.93   96189.63  148001.11  California  71498.49
# 44  22177.74  154806.14   28334.72  California  65200.33

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Subsetting rows and columns

# %%
D.iloc[3:8,1:4]
# Out:
#        ADMIN        MKT       STATE
# 3  118671.85  383199.62    New York
# 4   91391.77  366168.42     Florida
# 5   99814.71  362861.36    New York
# 6  147198.87  127716.82  California
# 7  145530.06  323876.68     Florida

# %%
D.loc[3:7,['ADMIN','MKT','STATE']]
# Out:
#        ADMIN        MKT       STATE
# 3  118671.85  383199.62    New York
# 4   91391.77  366168.42     Florida
# 5   99814.71  362861.36    New York
# 6  147198.87  127716.82  California
# 7  145530.06  323876.68     Florida

# %% [markdown]
# # DATA FILTERING
#
# FIND OUT STARTUPS WITH PROFIT > 150000

# %%
D[D['PROFIT']>150000]
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94
# 5  131876.90   99814.71  362861.36    New York  156991.12
# 6  134615.46  147198.87  127716.82  California  156122.51
# 7  130298.13  145530.06  323876.68     Florida  155752.60
# 8  120542.52  148718.95  311613.29    New York  152211.77

# %%
D.query("PROFIT>150000")
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94
# 5  131876.90   99814.71  362861.36    New York  156991.12
# 6  134615.46  147198.87  127716.82  California  156122.51
# 7  130298.13  145530.06  323876.68     Florida  155752.60
# 8  120542.52  148718.95  311613.29    New York  152211.77

# %%
D[(D['PROFIT']>120000)&(D['STATE']=='Florida')]
# Out:
#           RND      ADMIN        MKT    STATE     PROFIT
# 2   153441.51  101145.55  407934.54  Florida  191050.39
# 4   142107.34   91391.77  366168.42  Florida  166187.94
# 7   130298.13  145530.06  323876.68  Florida  155752.60
# 10  101913.08  110594.11  229160.95  Florida  146121.95
# 12   93863.75  127320.38  249839.44  Florida  141585.52
# 14  119943.24  156547.42  256512.92  Florida  132602.65
# 18   91749.16  114175.79  294919.57  Florida  124266.90

# %%
D.query("PROFIT>120000 & STATE=='California'")
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 1   162597.70  151377.59  443898.53  California  191792.06
# 6   134615.46  147198.87  127716.82  California  156122.51
# 9   123334.88  108679.17  304981.62  California  149759.96
# 11  100671.96   91790.61  249744.55  California  144259.40
# 13   91992.39  135495.07  252664.93  California  134307.35
# 16   78013.11  121597.55  264346.06  California  126992.93

# %%
D[(D['PROFIT']>=100000)&(D['PROFIT']<=150000)&(D['STATE']=='Forida')|(D['STATE']=='New York')]
# Out:
#           RND      ADMIN        MKT     STATE     PROFIT
# 0   165349.20  136897.80  471784.10  New York  192261.83
# 3   144372.41  118671.85  383199.62  New York  182901.99
# 5   131876.90   99814.71  362861.36  New York  156991.12
# 8   120542.52  148718.95  311613.29  New York  152211.77
# 15  114523.61  122616.84  261776.23  New York  129917.04
# 17   94657.16  145077.58  282574.31  New York  125370.37
# 19   86419.70  153514.11       0.00  New York  122776.86
# 21   78389.47  153773.43  299737.29  New York  111313.02
# 24   77044.01   99281.34  140574.81  New York  108552.04
# 27   72107.60  127864.55  353183.81  New York  105008.31
# 29   65605.48  153032.06  107138.38  New York  101004.64
# 31   61136.38  152701.92   88218.23  New York   97483.56
# 35   46014.02   85047.44  205517.64  New York   96479.51
# 38   20229.59   65947.93  185265.10  New York   81229.06
# 43   15505.73  127382.30   35534.17  New York   69758.98
# ...

# %%
D.query("PROFIT>=100000 and PROFIT<=150000 and STATE=='Florida' or STATE=='New York'")
# Out:
#           RND      ADMIN        MKT     STATE     PROFIT
# 0   165349.20  136897.80  471784.10  New York  192261.83
# 3   144372.41  118671.85  383199.62  New York  182901.99
# 5   131876.90   99814.71  362861.36  New York  156991.12
# 8   120542.52  148718.95  311613.29  New York  152211.77
# 10  101913.08  110594.11  229160.95   Florida  146121.95
# 12   93863.75  127320.38  249839.44   Florida  141585.52
# 14  119943.24  156547.42  256512.92   Florida  132602.65
# 15  114523.61  122616.84  261776.23  New York  129917.04
# 17   94657.16  145077.58  282574.31  New York  125370.37
# 18   91749.16  114175.79  294919.57   Florida  124266.90
# 19   86419.70  153514.11       0.00  New York  122776.86
# 21   78389.47  153773.43  299737.29  New York  111313.02
# 22   73994.56  122782.75  303319.26   Florida  110352.25
# 23   67532.53  105751.03  304768.73   Florida  108733.99
# 24   77044.01   99281.34  140574.81  New York  108552.04
# ...

# %% [markdown]
# ## Cars 93 query

# %%
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',30)

# %%
C
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %% [markdown]
# ## Find out car with compact type and mileage on city more than 15

# %%
C[(C['Type']=='Compact')&(C['MPG.city']>15)]
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# ...

# %%
C.query("Type=='Compact'and `MPG.city` > 15")
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# ...

# %%
C.query("Type=='Compact' and `MPG.city`>15")[['Manufacturer','Model','MPG.city','Type']]
# Out:
#      Manufacturer     Model  MPG.city     Type
# 2            Audi        90        20  Compact
# 11      Chevrolet  Cavalier        25  Compact
# 12      Chevrolet   Corsica        25  Compact
# 20       Chrysler   LeBaron        23  Compact
# 24          Dodge    Spirit        22  Compact
# 32           Ford     Tempo        22  Compact
# 42          Honda    Accord        24  Compact
# 54          Mazda       626        26  Compact
# 57  Mercedes-Benz      190E        20  Compact
# 64         Nissan    Altima        24  Compact
# 67     Oldsmobile   Achieva        24  Compact
# 73        Pontiac   Sunbird        23  Compact
# 77           Saab       900        20  Compact
# 81         Subaru    Legacy        23  Compact
# 89     Volkswagen    Passat        21  Compact
# 91          Volvo       240        21  Compact
